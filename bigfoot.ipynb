# %%
# import dependencies
# !pip install plotly.plotly
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly
import plotly as py
import plotly.offline as offline
import plotly.graph_objs as go

# %%
# Read dataset
df = pd.read_csv('Resources/bfro-report-locations.csv')
df.head()
# Out:
#                                             observed  \
# 0  I was canoeing on the Sipsey river in Alabama....
# 1  Ed L. was salmon fishing with a companion in P...
# 2  While attending U.R.I in the Fall of 1974,I wo...
# 3  Hello, My name is Doug and though I am very re...
# 4  It was May 1984. Two friends and I were up in ...
#
#                                     location_details  \
# 0                                                NaN
# 1                  East side of Prince William Sound
# 2             Great swamp area, Narragansett Indians
# 3  I would rather not have exact location (listin...
# 4  Logging roads north west of Yamhill, OR, about...
#
#                            county         state  season  \
# 0                  Winston County       Alabama  Summer
# 1  Valdez-Chitina-Whittier County        Alaska    Fall
# 2               Washington County  Rhode Island    Fall
# 3                     York County  Pennsylvania  Summer
# ...

# %%
# # split the timestamp to date and time columns
# df['dates'] = pd.to_datetime(df['timestamp']).dt.date
# df['time'] = pd.to_datetime(df['timestamp']).dt.time
# df.head()

# %%
#split title column into two columns
df[['Report', 'description']] = df['title'].str.split(':', 1, expand=True)
df.head()
# Out:
#                                             observed  \
# 0  I was canoeing on the Sipsey river in Alabama....
# 1  Ed L. was salmon fishing with a companion in P...
# 2  While attending U.R.I in the Fall of 1974,I wo...
# 3  Hello, My name is Doug and though I am very re...
# 4  It was May 1984. Two friends and I were up in ...
#
#                                     location_details  \
# 0                                                NaN
# 1                  East side of Prince William Sound
# 2             Great swamp area, Narragansett Indians
# 3  I would rather not have exact location (listin...
# 4  Logging roads north west of Yamhill, OR, about...
#
#                            county         state  season  \
# 0                  Winston County       Alabama  Summer
# 1  Valdez-Chitina-Whittier County        Alaska    Fall
# 2               Washington County  Rhode Island    Fall
# 3                     York County  Pennsylvania  Summer
# ...

# %%
# copy columns needed for project
df_clean = df[['number','county','state','season','date','latitude','longitude','description']].copy()
df_clean.head()
# Out:
#     number                          county         state  season        date  \
# 0  30680.0                  Winston County       Alabama  Summer         NaN
# 1   1261.0  Valdez-Chitina-Whittier County        Alaska    Fall         NaN
# 2   6496.0               Washington County  Rhode Island    Fall  1974-09-20
# 3   8000.0                     York County  Pennsylvania  Summer         NaN
# 4    703.0                  Yamhill County        Oregon  Spring         NaN
#
#    latitude  longitude                             description
# 0       NaN        NaN                                     NaN
# 1       NaN        NaN                                     NaN
# 2     41.45      -71.5   Bicycling student has night encounter
# 3       NaN        NaN                                     NaN
# 4       NaN        NaN                                     NaN

# %%
df_clean=df_clean.dropna()
df_clean
# Out:
#        number              county         state  season        date  latitude  \
# 2      6496.0   Washington County  Rhode Island    Fall  1974-09-20  41.45000
# 5      9765.0      Washita County      Oklahoma    Fall  1973-09-28  35.30110
# 6      4983.0   Washington County          Ohio  Summer  1971-08-01  39.38745
# 7     31940.0  Westchester County      New York    Fall  2010-09-01  41.29873
# 8      5692.0       Washoe County        Nevada    Fall  1970-09-01  39.59200
# ...       ...                 ...           ...     ...         ...       ...
# 5010  25257.0       Harlan County      Kentucky    Fall  2008-10-15  36.89771
# 5011  38980.0       Harlan County      Kentucky  Winter  2013-01-10  36.83193
# 5012   1045.0     Anderson County      Kentucky    Fall  2005-01-09  37.95708
# 5013  33187.0     Anderson County      Kentucky    Fall  2011-11-15  37.97699
# 5015  22941.0        Allen County      Kentucky  Spring  2002-04-15  36.77200
#
# ...

# %%
# check the total number of data per state on the clean df
count_per_state = df_clean['state'].value_counts()
count_per_state.head()
# Out:
# Washington    539
# Ohio          283
# Florida       281
# California    277
# Texas         218
# Name: state, dtype: int64

# %%
# save clean df to Resources folder
df_clean.to_csv('Resources/clean_data.csv', index=False)
