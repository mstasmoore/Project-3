# %%
# import dependencies
# !pip install plotly.plotly
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly
import plotly as py
import plotly.offline as offline
import plotly.graph_objs as go
from sqlalchemy import create_engine

# %%
# Read dataset
df = pd.read_csv('data/bfro-report-locations.csv')
df.head()
# Out:
#                                             observed  \
# 0  I was canoeing on the Sipsey river in Alabama....
# 1  Ed L. was salmon fishing with a companion in P...
# 2  While attending U.R.I in the Fall of 1974,I wo...
# 3  Hello, My name is Doug and though I am very re...
# 4  It was May 1984. Two friends and I were up in ...
#
#                                     location_details  \
# 0                                                NaN
# 1                  East side of Prince William Sound
# 2             Great swamp area, Narragansett Indians
# 3  I would rather not have exact location (listin...
# 4  Logging roads north west of Yamhill, OR, about...
#
#                            county         state  season  \
# 0                  Winston County       Alabama  Summer
# 1  Valdez-Chitina-Whittier County        Alaska    Fall
# 2               Washington County  Rhode Island    Fall
# 3                     York County  Pennsylvania  Summer
# ...

# %%
# # split the timestamp to date and time columns
# df['dates'] = pd.to_datetime(df['timestamp']).dt.date
# df['time'] = pd.to_datetime(df['timestamp']).dt.time
# df.head()

# %%
#split title column into two columns
df[['Report', 'description']] = df['title'].str.split(':', 1, expand=True)
df.head()
# Out:
#                                             observed  \
# 0  I was canoeing on the Sipsey river in Alabama....
# 1  Ed L. was salmon fishing with a companion in P...
# 2  While attending U.R.I in the Fall of 1974,I wo...
# 3  Hello, My name is Doug and though I am very re...
# 4  It was May 1984. Two friends and I were up in ...
#
#                                     location_details  \
# 0                                                NaN
# 1                  East side of Prince William Sound
# 2             Great swamp area, Narragansett Indians
# 3  I would rather not have exact location (listin...
# 4  Logging roads north west of Yamhill, OR, about...
#
#                            county         state  season  \
# 0                  Winston County       Alabama  Summer
# 1  Valdez-Chitina-Whittier County        Alaska    Fall
# 2               Washington County  Rhode Island    Fall
# 3                     York County  Pennsylvania  Summer
# ...

# %%
# copy columns needed for project
df_clean = df[['state','season','latitude','longitude','description']].copy()
df_clean
# Out:
#              state  season  latitude  longitude  \
# 0          Alabama  Summer       NaN        NaN
# 1           Alaska    Fall       NaN        NaN
# 2     Rhode Island    Fall     41.45      -71.5
# 3     Pennsylvania  Summer       NaN        NaN
# 4           Oregon  Spring       NaN        NaN
# ...            ...     ...       ...        ...
# 5016    New Mexico  Summer       NaN        NaN
# 5017      Maryland  Spring       NaN        NaN
# 5018       Florida  Summer       NaN        NaN
# 5019      Illinois    Fall       NaN        NaN
# 5020      Illinois  Summer       NaN        NaN
#
#                                  description
# 0                                        NaN
# 1                                        NaN
# 2      Bicycling student has night encounter
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 5016                                     NaN
# ...

# %%
df_clean=df_clean.dropna()
df_clean
# Out:
#              state  season  latitude  longitude  \
# 2     Rhode Island    Fall  41.45000  -71.50000
# 5         Oklahoma    Fall  35.30110  -99.17020
# 6             Ohio  Summer  39.38745  -81.67339
# 7         New York    Fall  41.29873  -73.73717
# 8           Nevada    Fall  39.59200 -119.97500
# ...            ...     ...       ...        ...
# 5010      Kentucky    Fall  36.89771  -83.16293
# 5011      Kentucky  Winter  36.83193  -83.42429
# 5012      Kentucky    Fall  37.95708  -84.97527
# 5013      Kentucky    Fall  37.97699  -84.90234
# 5015      Kentucky  Spring  36.77200  -86.14250
#
#                                             description
# 2                 Bicycling student has night encounter
# 5      Motorist and children have daylight sighting ...
# 6      Sighting and vocalizations at a home in Wayne...
# 7      Fishermen and Law Enforcement Officer Report ...
# 8       Father and son hear vocalizations on Peavine Mt
# ...

# %%
df_clean['type'] = "Big foot"
df_clean
# Out:
# /var/folders/22/yjz6fvvj5fd3rtnhmx3wq2840000gn/T/ipykernel_53973/3285055223.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              state  season  latitude  longitude  \
# 2     Rhode Island    Fall  41.45000  -71.50000
# 5         Oklahoma    Fall  35.30110  -99.17020
# 6             Ohio  Summer  39.38745  -81.67339
# 7         New York    Fall  41.29873  -73.73717
# 8           Nevada    Fall  39.59200 -119.97500
# ...            ...     ...       ...        ...
# 5010      Kentucky    Fall  36.89771  -83.16293
# 5011      Kentucky  Winter  36.83193  -83.42429
# 5012      Kentucky    Fall  37.95708  -84.97527
# 5013      Kentucky    Fall  37.97699  -84.90234
# 5015      Kentucky  Spring  36.77200  -86.14250
#
# ...

# %%
df_clean['season'].hist(bins=4)
plt.xlabel("Season of the Year")
plt.ylabel("Number of reports")
plt.title("Distribution of Big Foot reports by Season")
plt.savefig("Bigfoot_observations_by_seasons.png")

# %%
df_clean['state'].value_counts().plot(kind='bar',figsize=(20, 4));
plt.xlabel("Bigfoot Sighted State")
plt.ylabel("Total Count")
plt.title("Distribution of Big Foot By State")
plt.savefig("Bigfoot_by_State.png")

# %%
# df_clean = df[['state','season','date','latitude','longitude','description','type']].copy()
# df_clean

# %%
# # check the total number of data per state on the clean df
# count_per_state = df_clean['state'].value_counts()
# count_per_state.head()

# %%
# # !pip install folium
# import folium

# mymap = folium.Map(location=[33.3490, -96.5486],zoom_start=2)
# folium.Marker(location=[37.0902, -95.7129]).add_to(mymap)
# mymap

# %%
# # geocode big foot location from df to add markers on map
# Bigfoot_locations = list(zip(df_clean['latitude'].values, df_clean['longitude'].values))
# Bigfoot_locations[:5]

# %%
engine = create_engine("sqlite:///paranormal_activity.db")
df_clean.to_sql(name="paranormal", con=engine, if_exists="append", index=False)
pd.read_sql_query("select * from paranormal", con=engine).head()
# Out:
#                                          description                    city  \
# 0  3 differants types &#44 cluster &#44delta &#44...            connersville
# 1  Started off as 3 points of intense yellow ligh...  st. john&#39s (canada)
# 2  Bright lights with incredible agility seen fro...                  rachel
# 3  pulsating green white and red object in the no...              temperance
# 4  For two consecutive nights&#44 we watched a pa...          crescent beach
#
#   state country type   latitude   longitude  encounter_seconds season
# 0    in      us  UFO  39.641111  -85.141111            14400.0
# 1    nf      ca  UFO  47.550000  -52.666667             7200.0
# 2    nv      us  UFO  37.644722 -115.742778            10800.0
# 3    mi      us  UFO  41.779167  -83.568889            18000.0
# 4    sc      us  UFO  33.807500  -78.701111            37800.0
