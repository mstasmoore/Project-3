# %%
# import dependencies
# !pip install plotly.plotly
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly
import plotly as py
import plotly.offline as offline
import plotly.graph_objs as go
from sqlalchemy import create_engine

# %%
# Read dataset
df = pd.read_csv('Resources/bfro-report-locations.csv')
df.head()
# Out:
#                                             observed  \
# 0  I was canoeing on the Sipsey river in Alabama....
# 1  Ed L. was salmon fishing with a companion in P...
# 2  While attending U.R.I in the Fall of 1974,I wo...
# 3  Hello, My name is Doug and though I am very re...
# 4  It was May 1984. Two friends and I were up in ...
#
#                                     location_details  \
# 0                                                NaN
# 1                  East side of Prince William Sound
# 2             Great swamp area, Narragansett Indians
# 3  I would rather not have exact location (listin...
# 4  Logging roads north west of Yamhill, OR, about...
#
#                            county         state  season  \
# 0                  Winston County       Alabama  Summer
# 1  Valdez-Chitina-Whittier County        Alaska    Fall
# 2               Washington County  Rhode Island    Fall
# 3                     York County  Pennsylvania  Summer
# 4                  Yamhill County        Oregon  Spring
#
#                                                title  latitude  longitude  \
# 0                                                NaN       NaN        NaN
# 1                                                NaN       NaN        NaN
# 2  Report 6496: Bicycling student has night encou...     41.45      -71.5
# 3                                                NaN       NaN        NaN
# 4                                                NaN       NaN        NaN
#
#          date   number  ... moon_phase precip_intensity  precip_probability  \
# 0         NaN  30680.0  ...        NaN              NaN                 NaN
# 1         NaN   1261.0  ...        NaN              NaN                 NaN
# 2  1974-09-20   6496.0  ...       0.16              0.0                 0.0
# 3         NaN   8000.0  ...        NaN              NaN                 NaN
# 4         NaN    703.0  ...        NaN              NaN                 NaN
#
#    precip_type  pressure                 summary  uv_index  visibility  \
# 0          NaN       NaN                     NaN       NaN         NaN
# 1          NaN       NaN                     NaN       NaN         NaN
# 2          NaN   1020.61  Foggy until afternoon.       4.0        2.75
# 3          NaN       NaN                     NaN       NaN         NaN
# 4          NaN       NaN                     NaN       NaN         NaN
#
#    wind_bearing  wind_speed
# 0           NaN         NaN
# 1           NaN         NaN
# 2         198.0        6.92
# 3           NaN         NaN
# 4           NaN         NaN
#
# [5 rows x 28 columns]

# %%
# # split the timestamp to date and time columns
# df['dates'] = pd.to_datetime(df['timestamp']).dt.date
# df['time'] = pd.to_datetime(df['timestamp']).dt.time
# df.head()

# %%
#split title column into two columns
df[['Report', 'description']] = df['title'].str.split(':', 1, expand=True)
df.head()
# Out:
#                                             observed  \
# 0  I was canoeing on the Sipsey river in Alabama....
# 1  Ed L. was salmon fishing with a companion in P...
# 2  While attending U.R.I in the Fall of 1974,I wo...
# 3  Hello, My name is Doug and though I am very re...
# 4  It was May 1984. Two friends and I were up in ...
#
#                                     location_details  \
# 0                                                NaN
# 1                  East side of Prince William Sound
# 2             Great swamp area, Narragansett Indians
# 3  I would rather not have exact location (listin...
# 4  Logging roads north west of Yamhill, OR, about...
#
#                            county         state  season  \
# 0                  Winston County       Alabama  Summer
# 1  Valdez-Chitina-Whittier County        Alaska    Fall
# 2               Washington County  Rhode Island    Fall
# 3                     York County  Pennsylvania  Summer
# 4                  Yamhill County        Oregon  Spring
#
#                                                title  latitude  longitude  \
# 0                                                NaN       NaN        NaN
# 1                                                NaN       NaN        NaN
# 2  Report 6496: Bicycling student has night encou...     41.45      -71.5
# 3                                                NaN       NaN        NaN
# 4                                                NaN       NaN        NaN
#
#          date   number  ... precip_probability precip_type  pressure  \
# 0         NaN  30680.0  ...                NaN         NaN       NaN
# 1         NaN   1261.0  ...                NaN         NaN       NaN
# 2  1974-09-20   6496.0  ...                0.0         NaN   1020.61
# 3         NaN   8000.0  ...                NaN         NaN       NaN
# 4         NaN    703.0  ...                NaN         NaN       NaN
#
#                   summary  uv_index  visibility  wind_bearing  wind_speed  \
# 0                     NaN       NaN         NaN           NaN         NaN
# 1                     NaN       NaN         NaN           NaN         NaN
# 2  Foggy until afternoon.       4.0        2.75         198.0        6.92
# 3                     NaN       NaN         NaN           NaN         NaN
# 4                     NaN       NaN         NaN           NaN         NaN
#
#         Report                             description
# 0          NaN                                     NaN
# 1          NaN                                     NaN
# 2  Report 6496   Bicycling student has night encounter
# 3          NaN                                     NaN
# 4          NaN                                     NaN
#
# [5 rows x 30 columns]

# %%
# copy columns needed for project
df_clean = df[['state','season','date','latitude','longitude','description']].copy()
df_clean.head()
# Out:
#           state  season        date  latitude  longitude  \
# 0       Alabama  Summer         NaN       NaN        NaN
# 1        Alaska    Fall         NaN       NaN        NaN
# 2  Rhode Island    Fall  1974-09-20     41.45      -71.5
# 3  Pennsylvania  Summer         NaN       NaN        NaN
# 4        Oregon  Spring         NaN       NaN        NaN
#
#                               description
# 0                                     NaN
# 1                                     NaN
# 2   Bicycling student has night encounter
# 3                                     NaN
# 4                                     NaN

# %%
df_clean=df_clean.dropna()
df_clean
# Out:
#              state  season        date  latitude  longitude  \
# 2     Rhode Island    Fall  1974-09-20  41.45000  -71.50000
# 5         Oklahoma    Fall  1973-09-28  35.30110  -99.17020
# 6             Ohio  Summer  1971-08-01  39.38745  -81.67339
# 7         New York    Fall  2010-09-01  41.29873  -73.73717
# 8           Nevada    Fall  1970-09-01  39.59200 -119.97500
# ...            ...     ...         ...       ...        ...
# 5010      Kentucky    Fall  2008-10-15  36.89771  -83.16293
# 5011      Kentucky  Winter  2013-01-10  36.83193  -83.42429
# 5012      Kentucky    Fall  2005-01-09  37.95708  -84.97527
# 5013      Kentucky    Fall  2011-11-15  37.97699  -84.90234
# 5015      Kentucky  Spring  2002-04-15  36.77200  -86.14250
#
#                                             description
# 2                 Bicycling student has night encounter
# 5      Motorist and children have daylight sighting ...
# 6      Sighting and vocalizations at a home in Wayne...
# 7      Fishermen and Law Enforcement Officer Report ...
# 8       Father and son hear vocalizations on Peavine Mt
# ...                                                 ...
# 5010     ATV riders find possible tracks outside Evarts
# 5011   Teen on four-wheeler has sighting on family p...
# 5012   Father and son have a daylight encounter whil...
# 5013   Dual sighting in late afternoon by deer hunte...
# 5015   Man tells of Grandmother's encounters with sh...
#
# [4045 rows x 6 columns]

# %%
# check the total number of data per state on the clean df
count_per_state = df_clean['state'].value_counts()
count_per_state.head()
# Out:
# Washington    539
# Ohio          283
# Florida       281
# California    277
# Texas         218
# Name: state, dtype: int64

# %%
# !pip install folium
import folium

mymap = folium.Map(location=[33.3490, -96.5486],zoom_start=2)
folium.Marker(location=[37.0902, -95.7129]).add_to(mymap)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c16720e8394c502ddf7aef42b3da67b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c16720e8394c502ddf7aef42b3da67b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0c16720e8394c502ddf7aef42b3da67b = L.map(
#                 &quot;map_0c16720e8394c502ddf7aef42b3da67b&quot;,
#                 {
#                     center: [33.349, -96.5486],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21410f491352472fb68560f392faae78 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0c16720e8394c502ddf7aef42b3da67b);
#
#
#             var marker_b26d0240af6ae0814ecf1e4457a55e30 = L.marker(
#                 [37.0902, -95.7129],
#                 {}
#             ).addTo(map_0c16720e8394c502ddf7aef42b3da67b);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# geocode big foot location from df to add markers on map
Bigfoot_locations = list(zip(df_clean['latitude'].values, df_clean['longitude'].values))
Bigfoot_locations[:5]
# Out:
# [(41.45, -71.5),
#  (35.3011, -99.1702),
#  (39.38745, -81.67339),
#  (41.29873, -73.73717),
#  (39.592, -119.975)]

# %%
# Need to replace the name of the sqlite file
engine = create_engine('sqlite:///paranormal_activity.db')
# Need to replace the table na
df_clean.to_sql(name='paranormal', con=engine, if_exists='append', index=False)
# Need to read from right table to verify insertion of data
pd.read_sql_query('select * from paranormal', con=engine).head()
# Out:
#    id                                        description  city state  \
# 0   1  1. Airplane Boneyard, https://twistedsifter.co...  None  None
# 1   2  2. Mysterious Desert Pattern, https://twisteds...  None  None
# 2   3  3. Swastika-Shaped Building Complex, https://t...  None  None
# 3   4  4. Buffalo Herd, https://twistedsifter.com/wp-...  None  None
# 4   5  5. Giant Triangle, https://twistedsifter.com/w...  None  None
#
#     country  date  type   latitude   longitude encounter_seconds season
# 0       USA  None  None  32.149722 -110.835833              None   None
# 1     Egypt  None  None  27.380556   33.631667              None   None
# 2       USA  None  None  32.676111 -117.157500              None   None
# 3  Tanzania  None  None  -4.289167   31.396111              None   None
# 4       USA  None  None  33.747252 -112.633853              None   None
